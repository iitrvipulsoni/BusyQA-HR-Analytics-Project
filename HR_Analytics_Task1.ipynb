# %% [markdown]
# # Importing Pandas Library

# %%
#import pandas library

import pandas as pd

# %% [markdown]
# # Importing Train Data

# %%
#import excel file into a dataframe

df = pd.read_excel("E:/BusyQA/CO-OP HR Analytics/Data/Train_Data.xlsx")
df
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 2               46   city_16                   0.910     NaN
# 3            18527   city_64                   0.666    Male
# 4            21751  city_100                   0.887     NaN
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %%
#see dimension of the dataframe

df.shape
# Out:
# (18359, 14)

# %%
#see columns of the dataframe

df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
#see datatypes of each column of the dataframe

df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                      int64
# dtype: object

# %%
#creat a copy of the original dataframe to perform data cleaning and preparation

df_copy = pd.DataFrame(df.copy())

# %%
#see the copy of the dataframe

df_copy
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 2               46   city_16                   0.910     NaN
# 3            18527   city_64                   0.666    Male
# 4            21751  city_100                   0.887     NaN
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Data Cleaning and Manipulation
#
# ## Treating Null and Duplicate Values

# %%
#see the rows having atleast one null/missing value

nan_values = df_copy[df_copy.isna().any(axis=1)]

nan_values
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 2               46   city_16                   0.910     NaN
# 4            21751  city_100                   0.887     NaN
# 15           19752   city_75                   0.939    Male
# 19            2776  city_114                   0.926    Male
# 22           20897  city_136                   0.897     NaN
# ...            ...       ...                     ...     ...
# 18346         3611   city_61                   0.913     NaN
# 18347        19961  city_114                   0.926     NaN
# 18349         1448  city_175                   0.776  Female
# 18350        23546   city_90                   0.698    Male
# 18352        19092   city_90                   0.698  Female
#
#            relevent_experience enrolled_university education_level  \
# 2      Has relevent experience       no_enrollment        Graduate
# 4       No relevent experience       no_enrollment         Masters
# ...

# %%
#drop all the 9072 rows where atleast one value is null/missing from the copy of the dataframe

df_copy = df_copy.dropna()

# %%
#see the updated copy of the dataframe after removing all the rows having null/missing values

df_copy
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %%
#check for duplicate rows

df_copy[df_copy.duplicated()]
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target]
# Index: []

# %%
#dropping the duplicate values in case any

df_copy = df_copy.drop_duplicates()
df_copy
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Treating Categorical Data

# %%
#check the datatypes of each columns after performing data cleaning

df_copy.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                      int64
# dtype: object

# %%
#See unique values of each column with Object Datatype or String Datatype,i.e., Categorical Data

print('Gender column unique values: {}'.format(df_copy.gender.unique()))
print('Relevant Experience column unique values: {}'.format(df_copy.relevent_experience.unique()))
print('Enrolled University column unique values: {}'.format(df_copy.enrolled_university.unique()))
print('Education Level column unique values: {}'.format(df_copy.education_level.unique()))
print('Major Discipline column unique values: {}'.format(df_copy.major_discipline.unique()))
print('Experience column unique values: {}'.format(df_copy.experience.unique()))
print('Company Size column unique values: {}'.format(df_copy.company_size.unique()))
print('Company Type column unique values: {}'.format(df_copy.company_type.unique()))
print('Last New Job column unique values: {}'.format(df_copy.last_new_job.unique()))
print('Target column unique values: {}'.format(df_copy.target.unique()))
# Out:
# Gender column unique values: ['Male' 'Female' 'Other']
# Relevant Experience column unique values: ['Has relevent experience' 'No relevent experience']
# Enrolled University column unique values: ['no_enrollment' 'Full time course' 'Part time course']
# Education Level column unique values: ['Graduate' 'Masters' 'Phd']
# Major Discipline column unique values: ['STEM' 'Other' 'No Major' 'Business Degree' 'Humanities' 'Arts']
# Experience column unique values: [3 14 8 6 '>20' 4 9 15 10 16 12 5 13 11 7 19 1 2 17 '<1' 18 20]
# Company Size column unique values: ['100-500' '<10' '50-99' '5000-9999' '10000+' '1000-4999' '500-999'
#  datetime.datetime(1949, 10, 1, 0, 0)]
# Company Type column unique values: ['Pvt Ltd' 'Funded Startup' 'Public Sector' 'Early Stage Startup' 'NGO'
#  'Other']
# Last New Job column unique values: [1 2 3 '>4' 'never' 4]
# Target column unique values: [0 1]

# %%
#drop rows having redundant values in the gender column, i.e., gender = 'Other' shall be removed

df_copy = df_copy.drop(df_copy[(df_copy.gender == 'Other')].index)
df_copy
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %%
#check the updated unique values of the gender column

print(df_copy.gender.unique())
# Out:
# ['Male' 'Female']

# %%
#remove data entry error by updating one of the values in the 'company_size' column from datetime format to string,i.e.,'datetime.datetime(1949, 10, 1, 0, 0)' to '10-49'

df_copy['company_size'] = df_copy['company_size'].astype(str)

# %%
#replace the value '1949-10-01 00:00:00' with '10-49'

df_copy['company_size'] = df_copy['company_size'].replace(['1949-10-01 00:00:00'],'10-49')

#checking updated unique values in the 'company_size' column
df_copy['company_size'].unique()
# Out:
# array(['100-500', '<10', '50-99', '5000-9999', '10000+', '1000-4999',
#        '500-999', '10-49'], dtype=object)

# %%
#updated copy of the dataframe after performing data manipulation

df_copy
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 0            23798  city_149                   0.689    Male
# 1            29166   city_83                   0.923    Male
# 3            18527   city_64                   0.666    Male
# 5            13342   city_21                   0.624  Female
# 6            11746   city_21                   0.624    Male
# ...            ...       ...                     ...     ...
# 18354        25366  city_103                   0.920    Male
# 18355        25545  city_160                   0.920    Male
# 18356        11514  city_114                   0.926    Male
# 18357         1689   city_75                   0.939    Male
# 18358         5995  city_105                   0.794  Female
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1      Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Importing Matplotlib, Numpy, Seaborn Libraries

# %%
#import matplotlib, numpy, seaborn libraries

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# # Treating Numerical Data

# %%
#identify columns with int/float datatypes, i.e., Numerical Data

print(df_copy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9200 entries, 0 to 18358
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             9200 non-null   int64
#  1   city                    9200 non-null   object
#  2   city_development_index  9200 non-null   float64
#  3   gender                  9200 non-null   object
#  4   relevent_experience     9200 non-null   object
#  5   enrolled_university     9200 non-null   object
#  6   education_level         9200 non-null   object
#  7   major_discipline        9200 non-null   object
#  8   experience              9200 non-null   object
#  9   company_size            9200 non-null   object
#  10  company_type            9200 non-null   object
#  11  last_new_job            9200 non-null   object
#  12  training_hours          9200 non-null   int64
#  13  target                  9200 non-null   int64
# ...

# %% [markdown]
# Columns with Numerical Data are : 'enrollee_id', 'city_development_index', and 'training_hours'
#
# Note: Although, 'target' column has int64 datatype, however, it is considered as Categorical Data column due to the nature of the values this column has.

# %% [markdown]
# # Identifying and Treating Outliers

# %%
#use the describe function to see statistical data of the numerical columns

df_copy.describe()
# Out:
#         enrollee_id  city_development_index  training_hours       target
# count   9200.000000             9200.000000     9200.000000  9200.000000
# mean   16795.907609                0.860838       65.131848     0.106304
# std     9980.141300                0.101191       60.432729     0.308244
# min        2.000000                0.448000        1.000000     0.000000
# 25%     8092.500000                0.843000       23.000000     0.000000
# 50%    16699.500000                0.913000       47.000000     0.000000
# 75%    25916.500000                0.920000       88.000000     0.000000
# max    33380.000000                0.949000      336.000000     1.000000

# %%
#creating boxplot for 'city_development_index' column to check for outliers

plt.boxplot(df_copy['city_development_index'], vert=False)
plt.title("Detecting outliers using Boxplot")
plt.xlabel('values')
plt.ylabel('city_development_index')
plt.show()

# %%
#calculate boxplot parameters(Q1, Q3, IQR, Lower bound, Upper bound) to identify outlier values for the 'city_development_index' column

q1 = np.percentile(df_copy['city_development_index'], 25)
q3 = np.percentile(df_copy['city_development_index'], 75)
IQR = q3-q1
lower_bound = q1-(1.5*IQR)
upper_bound = q3+(1.5*IQR)

print('Lower bound is {}'.format(lower_bound))
print('Upper bound is {}'.format(upper_bound))
print('Minimum value in the city_development_index column is {}'.format(df_copy['city_development_index'].min()))
print('Maximum value in the city_development_index column is {}'.format(df_copy['city_development_index'].max()))
# Out:
# Lower bound is 0.7274999999999998
# Upper bound is 1.0355
# Minimum value in the city_development_index column is 0.448
# Maximum value in the city_development_index column is 0.949

# %% [markdown]
# All the values lesser than the lower bound and higher than the upper bound are considered as outliers.

# %%
#count of no. of rows having outlier values in the 'city_development_column'

print('No. of rows having values lesser than the lower bound are {}'.format(df_copy[df_copy['city_development_index'] < 0.7374999999999998].shape[0])) 
print('No. of rows having values higher than the upper bound are {}'.format(df_copy[df_copy['city_development_index'] > 1.0295].shape[0]))
# Out:
# No. of rows having values lesser than the lower bound are 1288
# No. of rows having values higher than the upper bound are 0

# %%
#checking percentage contribution of the rows having outlier values

1295/9200 * 100
# Out:
# 14.076086956521738

# %% [markdown]
# As 14.07% of rows has outliers values within the 'city_development_index' column, therefore, these values cannot be ignored during analysis.

# %%
#creating boxplot for 'training_hours' column to check for outliers

plt.boxplot(df_copy['training_hours'], vert=False)
plt.title("Detecting outliers using Boxplot")
plt.xlabel('values')
plt.ylabel('training_hours')
plt.show()

# %%
#calculate boxplot parameters(Q1, Q3, IQR, Lower bound, Upper bound) to identify outlier values for the 'training_hours' column

q1 = np.percentile(df_copy['training_hours'], 25)
q3 = np.percentile(df_copy['training_hours'], 75)
IQR = q3-q1
lower_bound = q1-(1.5*IQR)
upper_bound = q3+(1.5*IQR)

print('Lower bound is {}'.format(lower_bound))
print('Upper bound is {}'.format(upper_bound))
print('Minimum value in the training_hours column is {}'.format(df_copy['training_hours'].min()))
print('Maximum value in the training_hours column is {}'.format(df_copy['training_hours'].max()))
# Out:
# Lower bound is -74.5
# Upper bound is 185.5
# Minimum value in the training_hours column is 1
# Maximum value in the training_hours column is 336

# %%
#count of no. of rows having outlier values in the 'training_hours'

print('No. of rows having values lesser than the lower bound are {}'.format(df_copy[df_copy['training_hours'] < -74.5].shape[0])) 
print('No. of rows having values higher than the upper bound are {}'.format(df_copy[df_copy['training_hours'] > 185.5].shape[0]))
# Out:
# No. of rows having values lesser than the lower bound are 0
# No. of rows having values higher than the upper bound are 478

# %%
#checking percentage contribution of the rows having outlier values

478/9200 * 100
# Out:
# 5.195652173913044

# %% [markdown]
# As 5.19% of rows has outliers values within the 'training_hours' column, therefore, these values cannot be ignored during analysis.

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Univariate Analysis of continuous Variables

# %%
#plot histogram to visualize 'city_development_index' column values

plt.figure(figsize=(15,5))
plt.title("City Development Index wise Enrolees",size=20)
plt.xlabel('city_development_index', size=15)
plt.ylabel('No. of enrolees', size=15)
sns.histplot(df_copy.city_development_index, bins=int(20/1), color='green', edgecolor='black', kde=True)
# Out:
# <AxesSubplot:title={'center':'City Development Index wise Enrolees'}, xlabel='city_development_index', ylabel='No. of enrolees'>

# %% [markdown]
# Out of 9200 enrolees, more than 65% of them come from cities having city_development_index > 0.9.

# %%
#plot histogram to visualize 'training_hours' column values

plt.figure(figsize=(15,5))
plt.title("Training Hours wise enrolees",size=20)
plt.xlabel('city_development_index', size=15)
plt.ylabel('No. of enrolees', size=15)
sns.histplot(df_copy.training_hours, bins=int(20/1), color='green', edgecolor='black', kde=True)
# Out:
# <AxesSubplot:title={'center':'Training Hours wise enrolees'}, xlabel='city_development_index', ylabel='No. of enrolees'>

# %% [markdown]
# Out of 9200 enrolees, atleast 75% of them complete only 88 training hours.

# %% [markdown]
# # Bivariate Analysis of Continuous Variables

# %%
#use correlation function to calculate correlation coefficients for all continous variables

df_copy[['city_development_index','training_hours']].corr()
# Out:
#                         city_development_index  training_hours
# city_development_index                1.000000       -0.007466
# training_hours                       -0.007466        1.000000

# %% [markdown]
# Correlation matrix shows negative correlation between training hours and city development index with the insignificant value of 0.007466.

# %%
#plot scatterplot to see the trend amongst continous variables

plt.figure(figsize=(15,5))
plt.title("Scatter Plot between city_development_index VS training_hours",size=20)
plt.xlabel('city_development_index', size=15)
plt.ylabel('training_hours', size=15)
sns.scatterplot(df_copy.city_development_index, df_copy.training_hours, color='green')
plt.ylim(0,350)
# Out:
# C:\Users\Vipul Soni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 350.0)

# %% [markdown]
# No correlation between the 'city_development_index' and 'training_hours' columns.

# %%
#plot a barchart to compare how many numbers of enrolees looking for a new job OR not

plt.figure(figsize=(6,5))
plt.title("Target Wise Distribution of the Enrolees",size=15)
ax = sns.countplot(x=df_copy['target'],
                   order=df_copy['target'].value_counts(ascending=False).index);
        
abs_values = df_copy['target'].value_counts(ascending=False)
rel_values = df_copy['target'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '8222 (89%)'), Text(0, 0, '978 (11%)')]

# %% [markdown]
# Out of 9200 enrolees, 11% are looking for a new job.

# %%
#List out all the rows having enrolees who are looking for a new job,i.e., value in the 'target' column should be 1

df_copy[df_copy['target'] == 1]
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 6            11746   city_21                   0.624    Male
# 51           14257   city_21                   0.624    Male
# 65           26681  city_103                   0.920    Male
# 74           28674  city_160                   0.920    Male
# 81           11934  city_160                   0.920  Female
# ...            ...       ...                     ...     ...
# 18200        15154   city_78                   0.579    Male
# 18262         8840   city_91                   0.691    Male
# 18293        16869  city_103                   0.920  Female
# 18315        30649   city_70                   0.698  Female
# 18329        22908  city_136                   0.897    Male
#
#            relevent_experience enrolled_university education_level  \
# 6      Has relevent experience       no_enrollment        Graduate
# 51      No relevent experience    Full time course        Graduate
# ...

# %%
#storing all the rows of the enrolees who are looking for a job change in a new dataframe

df2 = df_copy[df_copy['target'] == 1]
df2
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 6            11746   city_21                   0.624    Male
# 51           14257   city_21                   0.624    Male
# 65           26681  city_103                   0.920    Male
# 74           28674  city_160                   0.920    Male
# 81           11934  city_160                   0.920  Female
# ...            ...       ...                     ...     ...
# 18200        15154   city_78                   0.579    Male
# 18262         8840   city_91                   0.691    Male
# 18293        16869  city_103                   0.920  Female
# 18315        30649   city_70                   0.698  Female
# 18329        22908  city_136                   0.897    Male
#
#            relevent_experience enrolled_university education_level  \
# 6      Has relevent experience       no_enrollment        Graduate
# 51      No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# # Bivariate Analysis of Categorical Variables vs Categorical Variables

# %% [markdown]
# ### Q1	Are males more inclined to looking for a new job as compared to females?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'gender' columns

plt.figure(figsize=(6,5))
plt.title("Gender Wise Distribution",size=15)
ax = sns.countplot(x=df2['gender'],
                   order=df2['gender'].value_counts(ascending=False).index);
        
abs_values = df2['gender'].value_counts(ascending=False)
rel_values = df2['gender'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '880 (90%)'), Text(0, 0, '98 (10%)')]

# %% [markdown]
# YES. Out of 978 enrolees who are looking for a new job, 90% of them are male.

# %% [markdown]
# ### Q2	Are private sector employees more inclined towards finding new jobs?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'company_type' columns

plt.figure(figsize=(8,6))
plt.title("Company Type Wise Distribution",size=15)
ax = sns.countplot(x=df2['company_type'],
                   order=df2['company_type'].value_counts(ascending=False).index);
        
abs_values = df2['company_type'].value_counts(ascending=False)
rel_values = df2['company_type'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '724 (74%)'),
#  Text(0, 0, '87 (9%)'),
#  Text(0, 0, '74 (8%)'),
#  Text(0, 0, '44 (4%)'),
#  Text(0, 0, '39 (4%)'),
#  Text(0, 0, '10 (1%)')]

# %% [markdown]
# YES. Out of 978 enrolees who are looking for a new job, 74% of them belong to private sector.

# %% [markdown]
# ### Q3	Do enrolees looking for new jobs frequently change their jobs or spend considerable time in their last job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'last_new_job' columns

plt.figure(figsize=(8,6))
plt.title("Last New Job Wise Distribution",size=15)
ax = sns.countplot(x=df2['last_new_job'],
                   order=df2['last_new_job'].value_counts(ascending=False).index);
        
abs_values = df2['last_new_job'].value_counts(ascending=False)
rel_values = df2['last_new_job'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '395 (40%)'),
#  Text(0, 0, '193 (20%)'),
#  Text(0, 0, '186 (19%)'),
#  Text(0, 0, '81 (8%)'),
#  Text(0, 0, '77 (8%)'),
#  Text(0, 0, '46 (5%)')]

# %% [markdown]
# Out of 978 enrolees who are looking for a new job, 40% of them change their jobs within 1 year and other 20% change their jobs within 2 years.

# %% [markdown]
# ### Q4	Are there any prominent cities where enrolees are more inclined to look for new job?

# %%
#groupby count of target=1 for all the cities then order them in descending order

df_copy_city_target = df_copy.groupby(['city','target'])['city'].count()
result = pd.DataFrame(df_copy_city_target).rename(columns={'city':'city','target':'target','city':'count'}).sort_values(by='count', ascending=False)
result = result.reset_index()
result.loc[result['target'] == 1]
# Out:
#          city  target  count
# 6    city_103       1    258
# 7     city_21       1    187
# 21    city_16       1     69
# 22   city_114       1     63
# 43   city_160       1     32
# ..        ...     ...    ...
# 198   city_80       1      1
# 199   city_81       1      1
# 200  city_157       1      1
# 201   city_12       1      1
# 202   city_18       1      1
#
# [89 rows x 3 columns]

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'city' columns

plt.figure(figsize=(20,20))
plt.title("City Wise Distribution",size=15)
ax = sns.countplot(y=df2['city'],
                   order=df2['city'].value_counts(ascending=False).index);
        
abs_values = df2['city'].value_counts(ascending=False)
rel_values = df2['city'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '258 (26%)'),
#  Text(0, 0, '187 (19%)'),
#  Text(0, 0, '69 (7%)'),
#  Text(0, 0, '63 (6%)'),
#  Text(0, 0, '32 (3%)'),
#  Text(0, 0, '19 (2%)'),
#  Text(0, 0, '18 (2%)'),
#  Text(0, 0, '17 (2%)'),
#  Text(0, 0, '15 (2%)'),
#  Text(0, 0, '13 (1%)'),
#  Text(0, 0, '11 (1%)'),
#  Text(0, 0, '11 (1%)'),
#  Text(0, 0, '11 (1%)'),
#  Text(0, 0, '10 (1%)'),
#  Text(0, 0, '9 (1%)'),
#  Text(0, 0, '9 (1%)'),
#  Text(0, 0, '8 (1%)'),
#  Text(0, 0, '8 (1%)'),
#  Text(0, 0, '8 (1%)'),
#  Text(0, 0, '7 (1%)'),
#  Text(0, 0, '7 (1%)'),
#  Text(0, 0, '7 (1%)'),
#  Text(0, 0, '7 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '6 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '5 (1%)'),
#  Text(0, 0, '4 (0%)'),
#  Text(0, 0, '4 (0%)'),
#  Text(0, 0, '4 (0%)'),
# ...

# %% [markdown]
# Yes. Out of 978 enrolees who are looking for a new job, below are the top 3 prominent cities:
# - 26% from city_103
# - 19% from city_21
# - 7% from city_16

# %% [markdown]
# ### Q5	Are enrolees with lower years of experience looking for a new job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'experience' columns

plt.figure(figsize=(20,20))
plt.title("Experience Wise Distribution",size=15)
ax = sns.countplot(y=df2['experience'],
                   order=df2['experience'].value_counts(ascending=False).index);
        
abs_values = df2['experience'].value_counts(ascending=False)
rel_values = df2['experience'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '158 (16%)'),
#  Text(0, 0, '72 (7%)'),
#  Text(0, 0, '66 (7%)'),
#  Text(0, 0, '66 (7%)'),
#  Text(0, 0, '65 (7%)'),
#  Text(0, 0, '60 (6%)'),
#  Text(0, 0, '59 (6%)'),
#  Text(0, 0, '58 (6%)'),
#  Text(0, 0, '43 (4%)'),
#  Text(0, 0, '38 (4%)'),
#  Text(0, 0, '38 (4%)'),
#  Text(0, 0, '37 (4%)'),
#  Text(0, 0, '35 (4%)'),
#  Text(0, 0, '32 (3%)'),
#  Text(0, 0, '28 (3%)'),
#  Text(0, 0, '27 (3%)'),
#  Text(0, 0, '24 (2%)'),
#  Text(0, 0, '22 (2%)'),
#  Text(0, 0, '22 (2%)'),
#  Text(0, 0, '10 (1%)'),
#  Text(0, 0, '10 (1%)'),
#  Text(0, 0, '8 (1%)')]

# %% [markdown]
# Out of 978 enrolees who are looking for a new job, approx. 51% of them have experience within 0-10 years and 16% have experience > 20 years.

# %% [markdown]
# ### Q6	Are non-STEM background enrolees are inclined for a new job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'major_discipline' columns

plt.figure(figsize=(11,6))
plt.title("Major Discipline Wise Distribution",size=15)
ax = sns.countplot(x=df2['major_discipline'],
                   order=df2['major_discipline'].value_counts(ascending=False).index);
        
abs_values = df2['major_discipline'].value_counts(ascending=False)
rel_values = df2['major_discipline'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '887 (91%)'),
#  Text(0, 0, '42 (4%)'),
#  Text(0, 0, '18 (2%)'),
#  Text(0, 0, '13 (1%)'),
#  Text(0, 0, '9 (1%)'),
#  Text(0, 0, '9 (1%)')]

# %% [markdown]
# NO. Out of 978 enrolees who are looking for a new job, only 9% of them are from non-STEM background.

# %% [markdown]
# # Bivariate Analysis of Categorical Variables vs Continuous Variables

# %% [markdown]
# ### Q7	Do enrolees looking for a new job spending high time in training?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'training_hours' and 'city_development_index' columns

df_copy.groupby(by='target').agg('mean')[['training_hours', 'city_development_index']]
# Out:
#         training_hours  city_development_index
# target
# 0            65.362077                0.865967
# 1            63.196319                0.817719

# %% [markdown]
# NO. Out of 9200 enrolees, only average 63.19 training hours are being completed by those who are looking for a new job.

# %% [markdown]
# # Other specific insights that can help us understand the drivers for job change?

# %% [markdown]
# ### Q8 Are enrolees with relevant experience more inclined towards looking for a new job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'relevent_experience' columns

plt.figure(figsize=(5,5))
plt.title("Relevant Experience Wise Distribution",size=15)
ax = sns.countplot(x=df2['relevent_experience'],
                   order=df2['relevent_experience'].value_counts(ascending=False).index);
        
abs_values = df2['relevent_experience'].value_counts(ascending=False)
rel_values = df2['relevent_experience'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '820 (84%)'), Text(0, 0, '158 (16%)')]

# %% [markdown]
# YES. Out of 978 enrolees who are looking for a new job, 84% of them have relevant work experience.

# %% [markdown]
# ### Q9 Does enrolees looking for a new job has been enrolled in any university?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'enrolled_university' columns

plt.figure(figsize=(7,6))
plt.title("University Enrollment Wise Distribution",size=15)
ax = sns.countplot(x=df2['enrolled_university'],
                   order=df2['enrolled_university'].value_counts(ascending=False).index);
        
abs_values = df2['enrolled_university'].value_counts(ascending=False)
rel_values = df2['enrolled_university'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '776 (79%)'), Text(0, 0, '139 (14%)'), Text(0, 0, '63 (6%)')]

# %% [markdown]
# YES. Out of 978 enrolees who are looking for a new job, 79% of them are not enrolled in any university.

# %% [markdown]
# ### Q10 How does current company size of enrolees matter in regards to inclination towards looking for a new job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'company_size' columns

plt.figure(figsize=(10,6))
plt.title("Company Size Wise Distribution",size=15)
ax = sns.countplot(x=df2['company_size'],
                   order=df2['company_size'].value_counts(ascending=False).index);
        
abs_values = df2['company_size'].value_counts(ascending=False)
rel_values = df2['company_size'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '201 (21%)'),
#  Text(0, 0, '197 (20%)'),
#  Text(0, 0, '176 (18%)'),
#  Text(0, 0, '114 (12%)'),
#  Text(0, 0, '102 (10%)'),
#  Text(0, 0, '80 (8%)'),
#  Text(0, 0, '63 (6%)'),
#  Text(0, 0, '45 (5%)')]

# %% [markdown]
# Out of 978 enrolees who are looking for a new job, 40% of them belong to 50-500 company size.

# %% [markdown]
# ### Q11 How does education level of enrolees matter in regards to inclination towards looking for a new job?

# %%
#plot countplot using seaborn library to perform bivariate analysis on 'target' and 'company_size' columns

plt.figure(figsize=(10,6))
plt.title("Education Level Wise Distribution",size=15)
ax = sns.countplot(x=df2['education_level'],
                   order=df2['education_level'].value_counts(ascending=False).index);
        
abs_values = df2['education_level'].value_counts(ascending=False)
rel_values = df2['education_level'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
# Out:
# [Text(0, 0, '698 (71%)'), Text(0, 0, '246 (25%)'), Text(0, 0, '34 (3%)')]

# %% [markdown]
# Out of 978 enrolees who are looking for a new job, 71% of them are graduates and 25% have masters degree.

# %%
#clean data file to excel

#df_copy.to_excel("E:/BusyQA/CO-OP HR Analytics/Data/Clean_Data.xlsx")
